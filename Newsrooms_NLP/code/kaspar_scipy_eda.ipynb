# %%
# %load_ext autoreload
# %autoreload 2

# %%
import nlp
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation

n_samples = 2000
n_features = 1000
n_components = 10
n_top_words = 20

corpus, labels = nlp.load_all('articles_db.db')
text = [article[0] for article in corpus]

# %%
def print_top_words(model, feature_names, n_top_words):
    print('Topics in:')
    print(str(model))
    for topic_idx, topic in enumerate(model.components_):
        message = f"----------  Topic #{topic_idx}:  ----------\n" 
        message += " ".join(
            [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]
        )
        print(message)
    print()

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=n_features,
                                   stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(text)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

nmf = NMF(n_components=n_components, random_state=1,
          alpha=.1, l1_ratio=.5).fit(tfidf)

#print("\nTopics in NMF model (Frobenius norm):")
print_top_words(nmf, tfidf_feature_names, n_top_words)
# Out:
# Topics in:
# NMF(alpha=0.1, beta_loss='frobenius', init=None, l1_ratio=0.5, max_iter=200,
#     n_components=10, random_state=1, shuffle=False, solver='cd', tol=0.0001,
#     verbose=0)
# ----------  Topic #0:  ----------
#   deal brexit support end likelier looks steps humiliation lawmakers eu win fail divorce rejected reject delays party pass crushed won
# ----------  Topic #1:  ----------
#   minister prime new says race british step uk woman exit humiliating britain eu stay citizens vote leave fails amid seek
# ----------  Topic #2:  ----------
#   trump brexit sue told says campaign turmoil away backs amid london latest eu pm uk british economic form final fails
# ----------  Topic #3:  ----------
#   parliament uk brexit rejects eu plans begin backs talks case government votes pm govt gives power process new exit loses
# ----------  Topic #4:  ----------
#   lawmakers delay uk approve reject brexit june asks eu latest british referendum talks 30 election govt day overwhelmingly seek minister
# ----------  Topic #5:  ----------
#   cameron david referendum eu resign date gets gamble british results markets uk calls case win economic leaving june pm major
# ----------  Topic #6:  ----------
#   theresa election government british brexit pm humiliation survives talks plan parliamentary remains week says cabinet gamble confidence confirms form vows
# ----------  Topic #7:  ----------
#   vote second brexit protest confidence key delays day week latest uk defeat step historic campaign departure theresa markets global crushed
# ----------  Topic #8:  ----------
#   britain brexit eu says exit want triggers historic leader fail turmoil decision court leaving referendum europe obama latest remain calls
# ----------  Topic #9:  ----------
#   50 article process starting trigger brexit week path assent royal uk pm british votes ruling triggers begins divorce begin court

# %%
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                max_features=n_features,
                                stop_words='english')
tf = tf_vectorizer.fit_transform(text)

lda = LatentDirichletAllocation(n_components=n_components, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=1)
lda.fit(tf)

#print("\nTopics in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Topics in:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='online', learning_offset=50.0,
#                           max_doc_update_iter=100, max_iter=5,
#                           mean_change_tol=0.001, n_components=10, n_jobs=None,
#                           perp_tol=0.1, random_state=1, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)
# ----------  Topic #0:  ----------
#   new leader brexit resign way making race june pm final party woman stage passes commons house deal approve negotiations lords
# ----------  Topic #1:  ----------
#   talks brexit end march theresa start asks says delay british deal uk respect leaders resign party parliament leaving stage parliamentary
# ----------  Topic #2:  ----------
#   referendum major sue stage cameron draft protest want david confirms looks leaders gives shattered asks fail final leaving backing corbyn
# ----------  Topic #3:  ----------
#   brexit 50 article backs trump away trigger process royal campaign britain anti assent starting week london johnson boris uk plan
# ----------  Topic #4:  ----------
#   brexit uk vote eu deal theresa parliament minister britain prime lawmakers delay british says trump cameron referendum talks plan exit
# ----------  Topic #5:  ----------
#   says trump sue told overwhelmingly poll woman stay rejected won amid path split eu rights negotiator crisis negotiations cameron process
# ----------  Topic #6:  ----------
#   theresa gamble referendum cameron parliamentary humiliation uk election minister brexit prime new eu article vote 50 win leader path second
# ----------  Topic #7:  ----------
#   brexit economy global market vote parliament uk british prime minister path backs deal defeat time britain protest humiliating 50 election
# ----------  Topic #8:  ----------
#   uk election brexit party june lawmakers labour approve survives leader britain british pm remains wins johnson crisis battle quits latest
# ----------  Topic #9:  ----------
#   brexit pm theresa form government british humiliation vows latest vote election week deal uk begin negotiations resign decision delay david

# %%
# Author: Olivier Grisel <olivier.grisel@ensta.org>
#         Lars Buitinck
#         Chyi-Kwei Yau <chyikwei.yau@gmail.com>
# License: BSD 3 clause

from time import time

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.datasets import fetch_20newsgroups

n_samples = 2000
n_features = 1000
n_components = 10
n_top_words = 20


def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()


# Load the 20 newsgroups dataset and vectorize it. We use a few heuristics
# to filter out useless terms early on: the posts are stripped of headers,
# footers and quoted replies, and common English words, words occurring in
# only one document or in at least 95% of the documents are removed.

print("Loading dataset...")
t0 = time()
dataset = fetch_20newsgroups(shuffle=True, random_state=1,
                             remove=('headers', 'footers', 'quotes'))
data_samples = dataset.data[:n_samples]
print("done in %0.3fs." % (time() - t0))

# Use tf-idf features for NMF.
print("Extracting tf-idf features for NMF...")
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=n_features,
                                   stop_words='english')
t0 = time()
tfidf = tfidf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))

# Use tf (raw term count) features for LDA.
print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                max_features=n_features,
                                stop_words='english')
t0 = time()
tf = tf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))
print()

# Fit the NMF model
print("Fitting the NMF model (Frobenius norm) with tf-idf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          alpha=.1, l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (Frobenius norm):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)

# Fit the NMF model
print("Fitting the NMF model (generalized Kullback-Leibler divergence) with "
      "tf-idf features, n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          beta_loss='kullback-leibler', solver='mu', max_iter=1000, alpha=.1,
          l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (generalized Kullback-Leibler divergence):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)

print("Fitting LDA models with tf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
lda = LatentDirichletAllocation(n_components=n_components, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
t0 = time()
lda.fit(tf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
